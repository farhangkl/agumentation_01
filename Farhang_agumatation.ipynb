# %%
# example of horizontal shift image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
from PIL import Image
import cv2
import sys
sys.modules['Image'] = Image 
from PIL import ImageEnhance

# %%
# load the image
img = cv2.imread('Far.jpg')

# %%
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator

datagen = ImageDataGenerator(width_shift_range=[-200,200])
it = datagen.flow(samples, batch_size=1)

datagen_shift= ImageDataGenerator(height_shift_range=0.5)
it_shift= datagen_shift.flow(samples, batch_size=1)

datagen_flip = ImageDataGenerator(horizontal_flip=True)
it_flip= datagen_flip.flow(samples, batch_size=1)

datagen_brightness = ImageDataGenerator(zoom_range=[0.2,1.0])
it_bright = datagen_brightness.flow(samples, batch_size=1)



# generate samples and plot
for i in range(9):
 # define subplot
 pyplot.subplot(330 + 1 + i)
 # generate batch of images
 batch = it.next()
 batch_shift = it_shift.next()
 batch_flip=it_flip.next()
 batch_brightness=it_bright.next()


 # convert to unsigned integers for viewing
 image = batch[0].astype('uint8')
 pyplot.imshow(image_shift)
 pyplot.imsave(str(i)+'.jpg',image )

  # plot raw pixel data
 #pyplot.imshow(image)
 
 image_shift = batch_shift[0].astype('uint8')
 pyplot.imsave('shift_'+str(i)+'.jpg',image_shift )

 image_flip = batch_flip[0].astype('uint8')
 pyplot.imsave('flip_'+str(i)+'.jpg',image_shift )

 #image_brightness = batch_brightness[0].astype('uint8')
# pyplot.imsave('brightness_'+str(i)+'.jpg',image_brightness)

    
  # plot raw pixel data
# show the figure
pyplot.show()

# %%
# example of brighting image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('Far.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imsave('str(i)+'.jpg',image )

# show the figure
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-67-9f6d993f53cb> in <module>
#       6 from matplotlib import pyplot
#       7 # load the image
# ----> 8 img = load_img('Far.jpg')
#       9 # convert to numpy array
#      10 data = img_to_array(img)
#
# ~/miniconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     106         color_mode = 'grayscale'
#     107     if pil_image is None:
# --> 108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
#     110     img = pil_image.open(path)
#
# ImportError: Could not import PIL.Image. The use of `load_img` requires PIL.
